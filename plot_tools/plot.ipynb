# %%
import numpy
import matplotlib

# %matplotlib inline
import matplotlib.pyplot
matplotlib.rcParams['figure.facecolor'] = 'white'

# %%
path = '/home/amigos/data/experiments/sisiv_logger/20181017_100658'

# %%
def plot_all(path, saveto=None, dpi=None):
    
    sis_list = ['2l', '2r', '3l', '3r',
                '4l', '4r', '5l', '5r', 
                '1lu', '1ll', '1ru', '1rl']
    
    voltage = numpy.loadtxt(path + '/sis_vol.txt')
    current = numpy.loadtxt(path + '/sis_cur.txt')
    
    ncol = 4
    nrow = 3
    nax = ncol * nrow
    
    matplotlib.rcParams['savefig.dpi'] = 50
    matplotlib.rcParams['font.size'] = 24
    
    figsize = (ncol * 8, nrow * 8)
    
    fig = matplotlib.pyplot.figure(figsize=figsize)
    ax = [fig.add_subplot(nrow, ncol, i+1) for i in range(nax)]
    
    for _ax, sis, _ in zip(ax, sis_list, range(len(sis_list))):
        _ax.plot(voltage[:, _], current[:, _], '.')
        _ax.grid()
        _ax.set_xlabel('vol [mV]')
        _ax.set_ylabel('cur [uA]')
        _ax.set_title('{}'.format(sis))
        
    fig.subplots_adjust(wspace=0.4, hspace=0.4)
    fig.suptitle(path + '\nNASCO IV MEASUREMENT on ROS', size=48)
    
    matplotlib.pyplot.savefig('./fig/{}.png'.format(path))
        
    matplotlib.pyplot.show()

# %%
plot_all(path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-1f17847b5815> in <module>()
# ----> 1 plot_all(path)
#
# <ipython-input-8-6642a4c9c22f> in plot_all(path, saveto, dpi)
#      30     fig.suptitle(path + '\nNASCO IV MEASUREMENT on ROS', size=48)
#      31
# ---> 32     matplotlib.pyplot.savefig('./fig/{}.png'.format(path))
#      33
#      34     matplotlib.pyplot.show()
#
# /home/amigos/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     695 def savefig(*args, **kwargs):
#     696     fig = gcf()
# --> 697     res = fig.savefig(*args, **kwargs)
#     698     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     699     return res
#
# /home/amigos/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/matplotlib/figure.py in savefig(self, *args, **kwargs)
#    1571             self.set_frameon(frameon)
#    1572
# -> 1573         self.canvas.print_figure(*args, **kwargs)
#    1574
#    1575         if frameon:
#
# /home/amigos/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2250                 orientation=orientation,
#    2251                 bbox_inches_restore=_bbox_inches_restore,
# -> 2252                 **kwargs)
#    2253         finally:
#    2254             if bbox_inches and restore_bbox:
#
# /home/amigos/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, *args, **kwargs)
#     548         renderer.dpi = self.figure.dpi
#     549         if is_string_like(filename_or_obj):
# --> 550             filename_or_obj = open(filename_or_obj, 'wb')
#     551             close = True
#     552         else:
#
# FileNotFoundError: [Errno 2] No such file or directory: './fig//home/amigos/data/experiments/sisiv_logger/20181017_100658.png'

# %%
power = numpy.loadtxt('./' + path + '/power.txt')
power2 = numpy.loadtxt('./' + path2 + '/power.txt')
fig = matplotlib.pyplot.figure()

ax = fig.add_subplot(1,1,1)
ax.plot(power[:, 1], color="b",  label = 'cold') # cold
ax.plot(power2[:, 1], color="r", label = 'hot') # hot
ax.grid()
ax.legend()
matplotlib.pyplot.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-3cffc14c492c> in <module>()
#       1 power = numpy.loadtxt('./' + path + '/power.txt')
# ----> 2 power2 = numpy.loadtxt('./' + path2 + '/power.txt')
#       3 fig = matplotlib.pyplot.figure()
#       4
#       5 ax = fig.add_subplot(1,1,1)
#
# NameError: name 'path2' is not defined
